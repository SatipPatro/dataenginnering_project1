# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import psycopg2 as psy

# %%
#define function for creating database 
def create_database():
    conn = psy.connect("host=127.0.0.1 dbname=postgres user=postgres password=12345")
    conn.set_session(autocommit=True)
    cur = conn.cursor()
    
    #create database
    cur.execute("Drop database if exists accounts")
    cur.execute("Create database accounts")
    
    #closing connection from default database
    conn.close()
    
    #connecting to the new database created
    conn= psy.connect("host=127.0.0.1 dbname=accounts user=postgres password=12345")
    conn.set_session(autocommit=True)
    cur=conn.cursor()
    
    return cur,conn

# %%
Accountdata = pd.read_csv("Wealth-AccountData.csv")

# %%
Accountdata.head()
# Out:
#   Country Name Country Code
# 0      Albania          ALB  \
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO  \
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10  \
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
Accountcountry=pd.read_csv("Wealth-AccountsCountry.csv")

# %%
Accountcountry.head()
# Out:
#   Code                  Long Name         Income Group
# 0  ALB        Republic of Albania  Upper middle income  \
# 1  ARG         Argentine Republic  Upper middle income
# 2  ARM        Republic of Armenia  Upper middle income
# 3  AUS  Commonwealth of Australia          High income
# 4  AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek  \
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census
# 0                                    2020 (expected)  \
# 1                                    2020 (expected)
# ...

# %%
AccountSeries=pd.read_csv("Wealth-AccountSeries.csv")

# %%
AccountSeries.head()
# Out:
#              Code                                     Indicator Name
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)  \
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition
# 0  Human capital is computed as the present value...  \
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital  \
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
Accountdata.columns,Accountcountry.columns,AccountSeries.columns
# Out:
# (Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#         '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#         '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#         '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#         '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#         '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#         '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#        dtype='object'),
#  Index(['Code', 'Long Name', 'Income Group', 'Region', 'Lending category',
#         'Other groups', 'Currency Unit', 'Latest population census',
#         'Latest household survey', 'Special Notes',
#         'National accounts base year', 'National accounts reference year',
#         'System of National Accounts', 'SNA price valuation',
#         'Alternative conversion factor', 'PPP survey years',
# ...

# %%
Accountdata_clean=Accountdata[['Country Name' , 'Country Code' , 'Series Name' , 'Series Code' ,'1995 [YR1995]' ,'2000 [YR2000]' ,'2005 [YR2005]' ,'2010 [YR2010]' ,'2015 [YR2015]']]

# %%
Accountcountry_clean=Accountcountry[['Code', 'Long Name','Short Name','Table Name','Currency Unit' ]]

# %%
Accountcountry_clean.head()
# Out:
#   Code                  Long Name Short Name Table Name      Currency Unit
# 0  ALB        Republic of Albania    Albania    Albania       Albanian lek
# 1  ARG         Argentine Republic  Argentina  Argentina     Argentine peso
# 2  ARM        Republic of Armenia    Armenia    Armenia      Armenian dram
# 3  AUS  Commonwealth of Australia  Australia  Australia  Australian dollar
# 4  AUT        Republic of Austria    Austria    Austria               Euro

# %%
AccountSeries_clean=AccountSeries[['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
        'Unit of measure']]

# %%
AccountSeries_clean.head()
# Out:
#              Code                                     Indicator Name
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)  \
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition
# 0  Human capital is computed as the present value...  \
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital  \
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
cur,conn =create_database()

# %%
accounts_data_tablecreate=("""CREATE TABLE IF NOT EXISTS accountsdata(
Country_Name varchar, 
Country_Code varchar, 
Series_Name varchar, 
Series_Code varchar,
YR1995 numeric,
YR2000 numeric,
YR2005 numeric,
YR2010 numeric,
YR2015 numeric)""")
cur.execute(accounts_data_tablecreate)
conn.commit()

# %%
accounts_country_tablecreate=("""CREATE TABLE IF NOT EXISTS accountscountry(
Code varchar, 
Long_Name varchar, 
Short_Name varchar, 
Table_Name varchar,
Currency_Unit varchar
)""")
cur.execute(accounts_country_tablecreate)
conn.commit()

# %%
accounts_series_tablecreate=("""CREATE TABLE IF NOT EXISTS accountsseries(
Code varchar, 
Long_Name varchar, 
Short_Name varchar, 
Table_Name varchar,
Currency_Unit varchar
)""")
cur.execute(accounts_series_tablecreate)
conn.commit()

# %%
accounts_data_table_insert=("""INSERT INTO  accountsdata(
Country_Name , 
Country_Code , 
Series_Name , 
Series_Code ,
YR1995 ,
YR2000 ,
YR2005 ,
YR2010 ,
YR2015 )
values (%s,%s,%s,%s,%s,%s,%s,%s,%s)
""")

# %%
 accounts_country_table_insert=("""INSERT INTO  accountscountry
 (Code, 
Long_Name, 
Short_Name, 
Table_Name,
Currency_Unit)
 values (%s,%s,%s,%s,%s)""")

# %%
#inserting rows from dataframe to country table through iterating
for i,row in Accountcountry_clean.iterrows():
    #print(i,list(row))
    cur.execute(accounts_country_table_insert,list(row))
conn.commit()

# %%
#inserting rows from dataframe to data table through iterating
for i,row in Accountdata_clean.iterrows():
    #print(i,list(row))
    cur.execute(accounts_data_table_insert,list(row))
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# InvalidTextRepresentation                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 #inserting rows from dataframe to data table through iterating
#       2 for i,row in Accountdata_clean.iterrows():
#       3     #print(i,list(row))
# ----> 4     cur.execute(accounts_data_table_insert,list(row))
#       5 conn.commit()
#
# InvalidTextRepresentation: invalid input syntax for type numeric: ".."
# LINE 11: ...assets: oil (constant 2018 US$)','NW.NCA.SAOI.PC','..','..',...
#                                                               ^

# %%
Accountdata_clean.head()
# Out:
#   Country Name Country Code
# 0      Albania          ALB  \
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO  \
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 2000 [YR2000]  2005 [YR2005]  2010 [YR2010]  2015 [YR2015]
# 0      4.49E+10      4.36E+10   5.440000e+10   6.810000e+10   7.370000e+10
# 1      14072.79      14118.13   1.807230e+04   2.336286e+04   2.559371e+04
# 2      3468.858      3424.007   2.222115e+03   2.889150e+03   2.987545e+03
# ...
